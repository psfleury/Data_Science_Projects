# %% [markdown]
# <a href="https://colab.research.google.com/github/psfleury/Data_Science_Projects/blob/main/2%20-%20Covid19/Panorama_do_COVID_19_no_Brasil_PedroFleury.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img alt="Colaboratory logo" width="15%" src="https://raw.githubusercontent.com/carlosfab/escola-data-science/master/img/novo_logo_bg_claro.png">
#
# #### **Data Science na Prática 3.0**
# *by [sigmoidal.ai](https://sigmoidal.ai)*
#
# ---

# %% [markdown]
# # Panorama do COVID-19 no Brasil
#
# A COVID-19 é uma doença infecciosa causada pelo novo coronavírus (SARS-CoV-2) e tem como principais sintomas febre, cansaço e tosse seca. Alguns pacientes podem apresentar dores, congestão nasal, dor de cabeça, conjuntivite, dor de garganta, diarreia, perda de paladar ou olfato, erupção cutânea na pele ou descoloração dos dedos das mãos ou dos pés. Esses sintomas geralmente são leves e começam gradualmente. Algumas pessoas são infectadas, mas apresentam apenas sintomas muito leves.
#
# A maioria das pessoas (cerca de 80%) se recupera da doença sem precisar de tratamento hospitalar. Uma em cada seis pessoas infectadas por COVID-19 fica gravemente doente e desenvolve dificuldade de respirar. As pessoas idosas e as que têm outras condições de saúde como pressão alta, problemas cardíacos e do pulmão, diabetes ou câncer, têm maior risco de ficarem gravemente doentes. No entanto, qualquer pessoa pode pegar a COVID-19 e ficar gravemente doente.
#
# <center><img alt="Colaboratory logo" width="70%" src="https://raw.githubusercontent.com/psfleury/Data_Science_Projects/main/2%20-%20Covid19/virus-da-covid.jpg"></center>
#
# Todos os vírus, incluindo o SARS-CoV-2, mudam com o tempo. Grande parte das mudanças tem pouco a nenhum impacto nas propriedades do vírus. Entretanto,de acordo com a Organização Mundial da Saúde (OMS), com a transmissão indiscriminada do vírus em diversas partes do mundo, não é raro que surjam mutações que afetem propriedades do vírus relevantes para a humanidade, tais como:
# * Taxa de transmissibilidade;
# * Severidade da infecção decorrente;
# * Performance de vacinas;
# * Adequação de medicamentos terapeuticos;
# * Ferramentas de diagnóstico;
# * Outras medidas de saúde pública e sociais.
#
# As variantes do SARS-CoV-2 que caracterizam um aumento de risco à saúde pública global passaram a ser classificadas em duas categorias pela OMS:
#
# i) **Variantes de Interesse (*Variants of Interest - VOI*)**, as quais contêm características que afetam a transmissibilidade, severidade, escapamento à imunidade adquirida, ao diagnóstico **ou** a tratamentos terapeuticos e que estejam causando transmissão comunitária ou múltiplos *clusters* de Covid-19, em diversos países, com aumento temporal de sua prevalência;
#
# ii) **Variantes Preocupantes (*Variants of Concern - VOC*)**, aquelas que se adequam à definição de Variante de Interesse (VOI) e, por meio de uma análise comparativa, tem demonstrado estar associada com **uma ou mais** das seguintes mudanças em termos de saúde pública global: a) aumento de transmissibilidade ou mudanças negativas na epidemiologia do Covid-19; ou b) Aumento de carga viral ou mudança na apresentação clínica da doença; ou c) Decréscimo na efetividade das medidas de saúde pública ou sociais ou dos diagnósticos disponíveis, das vacinas e procedimentos terapeuticos.
#
# As Variantes Preocupantes (VOC), até 17/08/2021, são quatro, classificadas da seguinte forma:
#
# * Alpha (B.1.1.7), surgida no Reino Unido em setembro/2020 e designada como VOC em 18/12/2020;
#
# * Beta (B.1.351), surgida na África do Sul em maio/2020 e designada como VOC em 18/12/2020;
#
# * Gamma (P.1), surgida no Brasil em novembro/2020 e designada como VOC em 11/01/2021;
#
# * Delta (B.1.617.2), surgida na Índia em outubro/2020 e designada como VOC em 11/05/2021.
#
# Desde o fim de 2020, pelo avanço de tais Variantes Preocupantes (VOC),  embora tenham ocorridos avanços sem precedentes no desenvolvimento de vacinas contra a Covid-19, mesmo países com alta taxa de imunização vacinal continuem com dificuldade de conter o avanço da doença, como é exemplo o Estados Unidos.

# %% [markdown]
# ## Obtenção dos Dados
#
# *Descreva a fonte dos seus dados e um breve resumo sobre o que se pode esperar desse dataset.*
#
# *Fale sobre a dificuldade de se analisar uma doença novas, os conflitos existentes entre os dados dos governos federal, estaduais e os não oficiais.*
#
# ### Dicionário de Variáveis
#
# **Nome do atributo - Descrição**
# * iso_code - Código de país ISO 3166, com 3 letras;
# * continent - Continente;
# * location - Localidade geográfica;
# * date - Data da observação;
# * total_cases - Quantidade acumulada de casos;
# * new_cases - Quantidade de novos casos;
# * new_cases_smoothed - Média móvel de novos casos em 7 dias;
# * total_deaths - Quantidade acumulada de mortes;
# * new_deaths - Quantidade de novas mortes;
# * new_deaths_smoothed - Média móvel de mortes em 7 dias;
# * total_cases_per_million - Quantidade acumulada de casos por milhão de pessoas;
# * new_cases_per_million - Quantidade de novos casos por milhão de pessoas;
# * new_cases_smoothed_per_million - Média móvel de novos casos em 7 dias por milhão de pessoas;
# * total_deaths_per_million - Quantidade acumulada de mortes por milhão de pessoas;
# * new_deaths_per_million - Quantidade de novas mortes por milhão de pessoas;
# * new_deaths_smoothed_per_million - Média móvel de novas mortes em 7 dias por milhão de pessoas;
# * reproduction_rate - Taxa de reprodução;
# * icu_patients - Pacientes em UTI no dia em questão;
# * icu_patients_per_million - Pacientes em UTI no dia em questão por milhão de pessoas;
# * hosp_patients - Pacientes hospitalizados no dia em questão;
# * hosp_patients_per_million - Pacientes hospitalizados no dia em questão por milhão de pessoas;
# * weekly_icu_admissions - Admissões em UTI na semana;
# * weekly_icu_admissions_per_million - Admissões em UTI na semana por milhão;
# * weekly_hosp_admissions - Admissões em hospital na semana;
# * weekly_hosp_admissions_per_million - Admissões em hospital na semana por milhão;
# * total_tests - Quantidade acumulada de testes;
# * new_tests - Quantidade de novos testes;
# * total_tests_per_thousand - Quantidade acumulada de testes por mil pessoas;
# * new_tests_per_thousand - Quantidade de novos testes por mil pessoas;
# * new_tests_smoothed - Média móvel de 7 dias para novos testes;
# * new_tests_smoothed_per_thousand - Média móvel de 7 dias para novos testes por mil pessoas;
# * positive_rate - Média móvel de 7 dias do percentual de testes que deram positivo;
# * tests_per_case - Média móvel de 7 dias de testes conduzidos por número de positivos identificados (inverso de 'positive_rate');
# * tests_units - Unidades usadas pela localidade para reportar seus dados de teste;
# * total_vaccinations - Quantidade total de vacinas administradas;
# * people_vaccinated - Quantidade total de pessoas que receberam ao menos uma dose de vacina;
# * people_fully_vaccinated - Quantidade total de pessoas que estão completamente vacinadas segundo o protocolo;
# * total_boosters - Número total de doses extras ao protocolo administradas;
# * new_vaccinations - Número de novas vacinas administradas;
# * new_vaccinations_smoothed - Média móvel de 7 dias de novas vacinas administradas;
# * total_vaccinations_per_hundred - Total de vacinas administradas por 100 pessoas;
# * people_vaccinated_per_hundred - Total de pessoas que receberam ao menos uma dose por 100 pessoas;
# * people_fully_vaccinated_per_hundred - Total de pessoas completamente vacinadas segundo o protocolo por 100 pessoas;
# * total_boosters_per_hundred - Número de doses extras administradas por 100 pessoas;
# * new_vaccinations_smoothed_per_million - Média móvel de 7 dias de novas doses administradas por milhão de pessoas;
# * stringency_index - Índice de rigor da resposta governamental, composto por nove indicadores, incluindo fechamento de escolas, de ambientes de trabalho, banimento de viagens, etc. Tal índice encontra-se entre 0 e 100.;
# * population - População do país em 2020;
# * population_density - Densidade populacional;
# * median_age - Idade mediana da população em 2020;
# * aged_65_older - Percentual da população com 65 anos ou mais;
# * aged_70_older - Percentual da população com 70 anos ou mais;
# * gdp_per_capita - PIB per capita do ano mais recente disponível;
# * extreme_poverty - Percentual da população vivendo em pobreza extrema;
# * cardiovasc_death_rate - Taxa de mortes por problema cardiovascular por cem mil pessoas;
# * diabetes_prevalence - Prevalência de diabetes na população (% da população com idade entre 20 e 79 anos);
# * female_smokers - Percentual das mulheres que fumavam no ano mais recente;
# * male_smokers - Percentual dos homens que fumavam no ano mais recente;
# * handwashing_facilities - Percentual da população com acesso a ambientes para lavagem de mão;
# * hospital_beds_per_thousand - Número de camas de hospital por 1000 pessoas, do ano mais recente;
# * life_expectancy - Expectativa de vida no nascimento em 2019;
# * human_development_index - Índice composto que mede atingimento em três dimensões básicas do desenvolvimento humano (Vida longa e saudável, conhecimento e decente padrão de vida), de acordo com valores de 2019.;
# * excess_mortality - P-valor de mortalidade em excesso, para todas as idades.
#
# ### Importando os dados do COVID-19
#
# * Os dados ora utilizados foram coletados de: [https://github.com/owid/covid-19-data/tree/master/public/data](https://github.com/owid/covid-19-data/tree/master/public/data).

# %%
# importar as bibliotecas necessárias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# importar o dataset COVID-19 para um DataFrame
df = pd.read_csv("https://raw.githubusercontent.com/psfleury/Data_Science_Projects/main/2%20-%20Covid19/owid-covid-data.csv",parse_dates=True, infer_datetime_format=True)

# %% [markdown]
# ## Análise Exploratória dos Dados (AED)
#
# Na AED acerca dos dados de Covid-19, serão feitas as seguintes abordagens:
#
# 1) Avaliam-se as dimensões do *dataset*, isto é, seu número de registros (linhas) e atributos (colunas);
#
# 2) Visualizam-se as primeiras e últimas linhas, de maneira a identificar o conteúdo, elidir qualquer dúvida que tenha surgido a partir do dicionário de dados construído, ou inferir qualquer característica que seja flagrantemente pertinente à análise a ser feita;
#
# 3) Faz-se uma análise de valores nulos da base, tentando entender o significado de tais ocorrências para cada atributo no contexto do *dataset*, bem como a estratégia utilizada para lidar com as ocorrências identificadas;
#
# 4) Avalia-se as estatísticas descritivas das colunas numéricas do *dataset*, com intuito de se identificar, no contexto do significado de cada atributo, *outliers* (valores extremos) que devam ser tratados;
#
# 5) Avalia-se a correlação entre as variáveis numéricas, permitindo obtenção do grau de associação entre variáveis, inclusive com plotagem de mapa de calor que represente a matriz decorrente;
#
# 6) Plotar um gráfico "stacked" de casos por continente de acordo com a data, inclusive com uma linha tangenciando;
#
# 7) Plotar um gráfico "stacked" de mortes por continente de acordo com a data, inclusive com uma linha tangenciando;
#
# 8) Avaliar a dispersão entre o PIB e a quantidade de mortos acumulada para a data mais recente;
#
# 9) Plotar um gráfico de barras horizontais animado com o número acumulado de casos por mês por país, desde o início da pandemia, para os 10 maiores países;
#
# 10) Plotar um gráfico de barras horizontais animado com o número acumulado de mortes por mês por país, desde o início da pandemia, para os 10 maiores países;
#
# 11) Plotar um mapa global com número de casos/população identificados por cores quentes (quanto mais quente, mais casos), para o mês selecionado;
#
# 12) Plotar um mapa global com número de mortes/população por cores quentes (quanto mais quente, mais mortes), para o mês selecionado;
#
# 13) Plotar um gráfico de barras de doses/habitante (vacinas) administradas no tempo;
#
# 14) Avaliar o comportamento do número de casos e de mortes em países em que surgiram Variantes Preocupantes (VOC).

# %% [markdown]
# **1) Avaliação das dimensões do *dataset***
#
# A base de dados avaliada possui 109.771 registros de acordo com 61 atributos de interesse, tal como descrito no dicionário de dados anteriormente destacado.

# %%
df.shape
# Out:
# (109771, 62)

# %% [markdown]
# **2) Verifica-se o conteúdo do início e fim do *dataset***
#
# Como se pode perceber, diversos atributos, no início da pandemia, logicamente, continham valores ausentes para cada país. À medida em que as nações foram se adequando à gestão da pandemia, foram conseguindo rastrear e fornecer dados estruturados para os diversos temas contemplados no *dataset*.
#
# Ressalva-se que a disponibilidade de dados depende da organização e efetiva gestão de cada país em relação à pandemia e, portanto, a presente análise possui limitações decorrentes dos dados fornecidos.

# %%
df.head(5)
# Out:
#   iso_code continent  ... human_development_index excess_mortality
# 0      AFG      Asia  ...                   0.511              NaN
# 1      AFG      Asia  ...                   0.511              NaN
# 2      AFG      Asia  ...                   0.511              NaN
# 3      AFG      Asia  ...                   0.511              NaN
# 4      AFG      Asia  ...                   0.511              NaN
#
# [5 rows x 62 columns]

# %%
df.loc[df.iso_code=='BRA'].tail(5)
# Out:
#       iso_code      continent  ... human_development_index excess_mortality
# 14452      BRA  South America  ...                   0.765              NaN
# 14453      BRA  South America  ...                   0.765              NaN
# 14454      BRA  South America  ...                   0.765              NaN
# 14455      BRA  South America  ...                   0.765              NaN
# 14456      BRA  South America  ...                   0.765              NaN
#
# [5 rows x 62 columns]

# %% [markdown]
# **3) Faz-se uma análise de valores nulos da base, tentando entender o significado de tais ocorrências para cada atributo no contexto do dataset, bem como a estratégia utilizada para lidar com as ocorrências identificadas;**
#
# Como se pode perceber da descrição dos atributos no dicionário de dados, há atributos cuja importância já era elevada desde o início da pandemia - Grupo 1, enquanto outros passaram a se tornar possíveis a partir das vacinas - Grupo 2, o que justifica que tenham grande parte da base como valores ausentes.
#
# A maior parte dos atributos pertencem ao Grupo 1, razão pela qual serão elencados abaixo o Grupo 2, com o respectivo percentual de valores ausentes, sendo os atributos do Grupo 1 definidos de forma residual/implícita:
# * total_boosters_per_hundred - 99,8%
# * total_boosters - 99,8%
# * people_fully_vaccinated_per_hundred - 83,7%
# * people_fully_vaccinated - 83,7%
# * new_vaccinations - 83,5%
# * people_vaccinated - 81%
# * people_vaccinated_per_hundred - 81%
# * total_vaccinations - 80,1%
# * total_vaccinations_per_hundred - 80,1%
# * new_vaccinations_smoothed_per_million - 65%
# * new_vaccinations_smoothed - 65%
#
# Portanto, para essas informações, embora haja muita representatividade de valores ausentes, esses valores simplemesmente não existiam em grande parte da pandemia, uma vez que as vacinas só começaram a ser aplicadas ao final de 2020 e, assim mesmo, iniciando com poucos países. Assim, tais atributos serão mantidos como ausentes e ignorados nos gráficos a serem plotados.
#
# Quanto aos atributos do Grupo 1, pela representatividade, descartam-se as colunas que possuem acima de 60% de seus valores ausentes, por não oferecer informações suficientes para uma análise. Nesse filtro ficaram compreendidos os seguintes atributos:
# * weekly_icu_admissions - 99,1%
# * weekly_icu_admissions_per_million - 99,1%
# * weekly_hosp_admissions - 98,2%
# * weekly_hosp_admissions_per_million - 98,2%
# * excess_mortality - 96,5%
# * icu_patients - 89,2%
# * icu_patients_per_million - 89,2%
# * hosp_patients - 87,1%
# * hosp_patients_per_million - 87,1%
#
# Quanto aos demais atributos do Grupo 1, serão mantidos como ausentes e ignorados para efeito de plotagem de gráficos.

# %%
# % de valores ausentes para cada atributo
(df.isnull().sum().sort_values(ascending=False)/df.shape[0]).head(60)
# Out:
# total_boosters                           0.998351
# total_boosters_per_hundred               0.998351
# weekly_icu_admissions_per_million        0.990544
# weekly_icu_admissions                    0.990544
# weekly_hosp_admissions_per_million       0.981653
# weekly_hosp_admissions                   0.981653
# excess_mortality                         0.964708
# icu_patients_per_million                 0.892212
# icu_patients                             0.892212
# hosp_patients_per_million                0.870540
# hosp_patients                            0.870540
# people_fully_vaccinated                  0.836860
# people_fully_vaccinated_per_hundred      0.836860
# new_vaccinations                         0.834920
# people_vaccinated                        0.809640
# people_vaccinated_per_hundred            0.809640
# total_vaccinations_per_hundred           0.801204
# total_vaccinations                       0.801204
# new_vaccinations_smoothed_per_million    0.649771
# ...

# %%
a_remover_grupo1 = ['weekly_icu_admissions',
    'weekly_icu_admissions_per_million',
    'weekly_hosp_admissions',
    'weekly_hosp_admissions_per_million',
    'excess_mortality',
    'icu_patients',
    'icu_patients_per_million',
    'hosp_patients',
    'hosp_patients_per_million']

# %%
# Removendo atributos do grupo 1 que possuam acima de 60% de valores ausentes
df.drop(a_remover_grupo1, axis=1, inplace=True)

# %%
df.head()
# Out:
#   iso_code continent  ... life_expectancy human_development_index
# 0      AFG      Asia  ...           64.83                   0.511
# 1      AFG      Asia  ...           64.83                   0.511
# 2      AFG      Asia  ...           64.83                   0.511
# 3      AFG      Asia  ...           64.83                   0.511
# 4      AFG      Asia  ...           64.83                   0.511
#
# [5 rows x 53 columns]

# %% [markdown]
# **4) Avaliam-se as estatísticas descritivas das colunas numéricas do *dataset*, com intuito de se identificar, no contexto do significado de cada atributo, *outliers* (valores extremos) que devam ser tratados;**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109771 entries, 0 to 109770
# Data columns (total 53 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   iso_code                               109771 non-null  object
#  1   continent                              104697 non-null  object
#  2   location                               109771 non-null  object
#  3   date                                   109771 non-null  object
#  4   total_cases                            105026 non-null  float64
#  5   new_cases                              105023 non-null  float64
#  6   new_cases_smoothed                     104013 non-null  float64
#  7   total_deaths                           94578 non-null   float64
#  8   new_deaths                             94733 non-null   float64
#  9   new_deaths_smoothed                    104013 non-null  float64
# ...

# %%
fig, ax = plt.subplots()

# %% [markdown]
# ## **Visualização de Dados**
# Campos importantes para gráficos/visualização de dados:
# * iso_code,
# * continent,
# * date,
# * total_cases,
# * new_cases,
# * new_cases_smoothed,
# * total_cases_per_million,
# * new_cases_per_million,
# * new_cases_smoothed_per_million,
# * total_deaths,
# * new_deaths,
# * new_deaths_smoothed,
# * new_cases_smoothed_per_million,
# * total_deaths_per_million,
# * new_deaths_per_million,
# * new_deaths_smoothed_per_million,
# * total_tests,
# * new_tests,
# * total_tests_per_thousand,
# * new_tests_per_thousand,
# * new_tests_smoothed,
# * new_tests_smoothed_per_thousand,
# * aged_65_older,
# * aged_70_older,
# * gdp_per_capita,
# * extreme_poverty,
# * cardiovasc_death_rate,
# * diabetes_prevalence,
# * human_development_index;

# %% [markdown]
# **a) Comportamento de casos, por continente, de acordo com a data, inclusive com uma linha tangenciando;**

# %%
[date]

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.stackplot(df.date, df.new_cases, labels=df.continent)
ax.set_title('Covid-19')
ax.legend(loc='upper left')
ax.set_ylabel('Número de Casos')
ax.set_xlabel('Período')
ax.set_xlim(xmin=min(df.index), xmax=max(df.index))
fig.tight_layout()

# %% [markdown]
# ### Análise Exploratória para o Brasil
#
# * Criar uma cópia do DataFrame apenas com o Brasil
#     * `df_brasil = df.loc[df.location == "Brazil"].copy()`
# * Identificar quando foi registrada a primeira morte no Brasil
# * Identificar quantos dias demorou para registrarmos a primeira morte, considerando o primeiro caso de COVID-19 registrado.
# * Plotar gráficos de linha em escalas linear e logarítmica para os casos totais e mortes totais.

# %% [markdown]
# ## Conclusão
#
# *Escreva suas conclusões e análises sobre os dados relativos à COVID-19...*
